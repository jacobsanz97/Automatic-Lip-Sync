# %%
import matplotlib.pyplot as plt


epoch = [1, 2, 3, 5, 8, 10, 13, 15, 20]

tr_acc = [0.730,0.827,0.850,0.877,0.902,0.919,0.962,0.982,0.996]
tr_loss = [0.627,0.432,0.360,0.317,0.254,0.234,0.150,0.112,0.044]
test_acc = [0.730,0.763,0.795,0.803,0.832,0.838,0.814,0.820,0.803]

plt.plot(epoch, tr_acc, label='Training Accuracy')
plt.plot(epoch, tr_loss, label = 'Training Loss')
plt.plot(epoch, test_acc, label='Test Accuracy')

legend = plt.legend(shadow=True)

plt.xlabel('Epochs')
plt.ylabel('Percentage')
plt.title('')
plt.show()
